# %%
import sys
import os
from util import Score_calculate as score
from transformers import T5Tokenizer, T5ForConditionalGeneration
import pandas as pd
from tqdm import tqdm
import torch

# %%
# Define generation function
def generate_smiles_from_caption(caption, tokenizer, model, max_length=128):
    inputs = tokenizer(caption, return_tensors="pt", truncation=True).to(model.device)
    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_length=max_length,
            num_beams=5,
            early_stopping=True
        )
    decoded = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return decoded.strip()

# %%
# SingMolT5 Model Generation and metrics computation

# Load model and tokenizer
tokenizer = T5Tokenizer.from_pretrained(R"YOUR_MODEL_PATH/SingMolT5_small", model_max_length=128)
model = T5ForConditionalGeneration.from_pretrained(R'YOUR_MODEL_PATH/SingMolT5_small')

# Load testing dataset
df = pd.read_csv("Dataset/MolGen_Test.csv")
captions = df["Caption"].tolist()
true_smiles = df["SMILES"].tolist()

# Set cuda
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Generate SMILES strings
ft_generated_smiles = []
for caption in tqdm(captions, desc="Generating SMILES"):
    pred = generate_smiles_from_caption(caption, tokenizer, model)
    ft_generated_smiles.append(pred)

# Compute evaluation metrics
with score.suppress_rdkit_warnings():
    results = score.evaluate_batch(true_smiles, ft_generated_smiles)

score.result_output(results)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Generating SMILES: 100%|██████████| 60/60 [00:11<00:00,  5.11it/s]
# === Evaluation Results (Average over Batch) ===
# BLEU                  : 0.3132
# Levenshtein Similarity: 0.4684
# MACCS FTS             : 0.3682
# RDK FTS               : 0.2091
# Morgan FTS            : 0.2350
# Validity              : 0.9667

# %%
# MolT5 Model Generation and metrics computation

# Load model and tokenizer
tokenizer = T5Tokenizer.from_pretrained(R"YOUR_MODEL_PATH/MolT5small_Cap2Sm", model_max_length=128)
model = T5ForConditionalGeneration.from_pretrained(R'YOUR_MODEL_PATH/MolT5small_Cap2Sm')

# Load testing dataset
df = pd.read_csv("Dataset/MolGen_Test.csv")
captions = df["Caption"].tolist()
true_smiles = df["SMILES"].tolist()

# Set cuda
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Generate SMILES strings
mt5_generated_smiles = []
for caption in tqdm(captions, desc="Generating SMILES"):
    pred = generate_smiles_from_caption(caption, tokenizer, model)
    mt5_generated_smiles.append(pred)

v
with score.suppress_rdkit_warnings():
    results = score.evaluate_batch(true_smiles, mt5_generated_smiles)

score.result_output(results)
# Out:
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# /usr/local/anaconda3/envs/zyhEnv/lib/python3.8/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# Generating SMILES: 100%|██████████| 60/60 [00:22<00:00,  2.68it/s]
# === Evaluation Results (Average over Batch) ===
# BLEU                  : 0.3285
# Levenshtein Similarity: 0.4600
# MACCS FTS             : 0.2827
# RDK FTS               : 0.1336
# Morgan FTS            : 0.1288
# Validity              : 0.8333

# %%
# T5 Model Generation and metrics computation

# Load model and tokenizer
tokenizer = T5Tokenizer.from_pretrained(R"YOUR_MODEL_PATH/T5small_Cap2Sm", model_max_length=128)
model = T5ForConditionalGeneration.from_pretrained(R'YOUR_MODEL_PATH/T5small_Cap2Sm')

# Load testing dataset
df = pd.read_csv("Dataset/MolGen_Test.csv")
captions = df["Caption"].tolist()
true_smiles = df["SMILES"].tolist()

# Set cuda
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Generate SMILES strings
t5_generated_smiles = []
for caption in tqdm(captions, desc="Generating SMILES"):
    pred = generate_smiles_from_caption(caption, tokenizer, model)
    t5_generated_smiles.append(pred)

# Compute evaluation metrics
with score.suppress_rdkit_warnings():
    results = score.evaluate_batch(true_smiles, t5_generated_smiles)

score.result_output(results)
# Out:
# Generating SMILES: 100%|██████████| 60/60 [00:26<00:00,  2.26it/s]
# === Evaluation Results (Average over Batch) ===
# BLEU                  : 0.3555
# Levenshtein Similarity: 0.4649
# MACCS FTS             : 0.1830
# RDK FTS               : 0.0908
# Morgan FTS            : 0.0865
# Validity              : 0.5667

# %%
print(ft_generated_smiles)
# Out:
# ['C1=CC=C(C=C1)C#N', 'C1=CC=C(C=C1)C#N', 'C1=CC=C(C=C1)C#N', 'C1=CC=C(C=C1)C2=CC=CC=C2', 'C1=CC=C(C=C1)C#CC2=CC=CC=C2', 'CCC1=CC=C(C=C1)C#CC2=CC=CC=C2', 'CSC1=CC=C(C=C1)S', 'CSC1=CC=C(C=C1)S', 'CSC1=CC=C(C=C1)S', 'C1=CC=C(C=C1)Br', 'C1=CC=C(C=C1)Br', 'C1=CC=C(C=C1)Br', 'CSC1=CC=C(C=C1)SC', 'CSC1=CC=C(C=C1)SC', 'CSC1=CC=C(C=C1)SC', 'CSC1=CC=C(C=C1)S', 'C1=CC=CC=C1S', 'C1=CC=C(C=C1)S', 'C1=CC=C(C=C1)S', 'CSC1=CC=C(C=C1)S', 'C1=CC=C(C=C1)S', 'CSC1=CC=C(C=C1)N', 'C1=CC=C(C=C1)C#N', 'CSC1=CC=C(C=C1)N', 'C1=CC=C(C=C1)C#N', 'C1=CC=C(C=C1)C#N', 'C1=CC=C(C=C1)C#N', 'C1=CC=C(C=C1)I', 'C1=CC=C(C=C1)I', 'C1=CC=C(C=C1)I', 'C1=CC=C(C=C1)SC', 'C1=CC=C(C=C1)SC', 'C1=CC=C(C=C1)S', 'C1=CC=C(C=C1)C#N', 'C1=CC=C(C=C1)SC', 'C1=CC=C1', 'C1=CC=C(C=C1)C#N', 'C1=CC=C(C=C1)C#N', 'C1=CC=C(C=C1)N', 'C1=CC=C(C=C1)C2=CC=C(C=C2)C=C1', 'C1=CC=C(C=C1)C#N', 'C1=CC=C(C=C1)C#CC2=CC=C(C=C2)C#N', 'CSC1=CC=C(C=C1)S', 'CSC1=CC=C(C=C1)SC', 'CSC1=CC=C(C=C1)S', 'CC1=CC=C(C=C1)C#CC2=CC=CC=C2', 'CSC1=CC=C(C=C1)C#N', 'CNC1=CC=C(C=C1)C#N', 'C1=CC=C(C=C1)C#N', 'C1=CC=C(C=C1)C#N', 'C1=CC=C(C=C1)C2=CC=C(C=C2)C=C1', 'C1=CC=C(C=C1)N', 'C1=CC=C(C=C1)N', 'C1=CC=C(C=C1)N', 'C1=CC=C(C=C1)N', 'C1=CC=C(C=C1)C#N', 'C1=CC=C(C=C1)N', 'C1=CC=C(C=C1)C#N', 'C1=CC=C(C=C1)C#N', 'C1=CC=C(C=C1)C(=O)O']

# %%
print(mt5_generated_smiles)
# Out:
# ['C1=C(C(=O)NC(=O)N1)C(=O)O', 'CC(=O)C1=CNC(=O)C1', 'C1=CC=NC(=C1N)C(=O)O', 'C1=CC=C(C(=C1)C2=CC=CC=C2C(=O)O)C(=O)O', 'C1=CC=C(C=C1)C(C2=CC=CC=C2)C3=CC=CC=C3', 'CC1=C(C=C(C=C1)C2=CC=CC=C2C(=O)N)C3=CC=C(C=C3)C4=CC=CC=C4', 'C1=CC=C2C(=C1)C(=CN2)C3=C(C=C(C=C3)S(=O)(=O)N', 'C/C(=CC(=O)O